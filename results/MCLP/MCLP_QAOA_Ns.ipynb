# %%
import sys, os
sys.path.append(os.path.abspath('../../'))
import setup_path

# %%
import numpy as np
import pandas
from collections import defaultdict
import random
import time

from docplex.mp.model import Model
import cplex

from src.problems.MCLP import get_neighbors, MCLP
from src.utils.cplex_helpers import solution, cont_solution, check_feasibility, WS_parameters
from src.utils.OQUBO import DocplexModeltoQUBO, QUBOtoIsingModel
from src.utils.helpers import compute_expect, compute_cost, BruteForceSolutions

import datetime
import yfinance as yf

import qiskit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
from qiskit import QuantumCircuit, transpile
from qiskit.circuit import Parameter
from qiskit.quantum_info import Statevector, DensityMatrix, Pauli
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

from qiskit.circuit.library import efficient_su2
from qiskit.circuit import ParameterVector

# %%
with open("data_MCLP_.txt", "r") as file:
    instances_dict = eval(file.read())

# %%
def min_QAOA(model, ising_model, p, backend, LR=False, WS_params=None, iters=500):
    enrgs = []
    probs_opt = []
    def Cost_function(params, ising_model, model, quantum_circuit, backend, p, gammas, betas, LR=False, minimize=True):
        global n_iters
        
        if LR:
            gamma_vals = np.arange(1, p + 1) * params[0]/p # Annealing liear ramp schecule (cost hamiltonian)
            beta_vals = np.arange(1, p + 1)[::-1] * params[1]/p # Annealing liear ramp schedule (mixer term)
        else:
            gamma_vals = params[:p]
            beta_vals =  params[p:]
        
        bind_dict = {gammas[i]: gamma_vals[i] for i in range(len(gamma_vals))}
        bind_dict.update({betas[i]: beta_vals[i]   for i in range(len(beta_vals))})
        qc_exec = quantum_circuit.assign_parameters(bind_dict)
    
        shots = 1000
        result = backend.run(qc_exec, shots=shots).result().get_counts() 
    
        opt_sol = solution(model)
        prob_opt = result.get(opt_sol,0)/shots
        energy_qubo = compute_cost(result, ising_model)
        enrgs.append(energy_qubo)
        probs_opt.append(prob_opt)
        if minimize:
            return energy_qubo
        else: 
            return energy_qubo, result
    
    n_qubits = model.number_of_variables
    gammas = ParameterVector('γ', length=p)
    betas = ParameterVector('β', length=p)
    
    hamiltonian, ising_constant = ising_model
    
    ansatz = QuantumCircuit(n_qubits)

    if WS_params:
        for i, param in enumerate(WS_params):
            ansatz.ry(param, i)
    else:
        ansatz.h(range(n_qubits))
        
    for ii in range(p):
        for qbits, value in hamiltonian.items():
            if qbits[0] == qbits[1]:
                ansatz.rz(2*gammas[ii]*float(value), qbits[0])
        for qbits, value in hamiltonian.items():
            if qbits[0] != qbits[1]:
                ansatz.rzz(2*gammas[ii]*float(value), *qbits)
        if WS_params:
            for i, param in enumerate(WS_params):
                ansatz.ry(-param, i)
            ansatz.rz(-2*betas[ii], range(n_qubits))
            for i, param in enumerate(WS_params):
                ansatz.ry(param, i)
        else:
            ansatz.rx(-2*betas[ii], range(n_qubits))
            
    ansatz = ansatz.reverse_bits()
    ansatz.measure_all()
    gates = dict(ansatz.count_ops())
    
    # Transpile the ansatz circuit for the given backend
    qc = transpile(ansatz)
    
    if LR:
        delta_gamma = np.random.random() 
        delta_beta = np.random.random() 
        params = [delta_gamma, delta_beta]
        bounds_params = [(0.0000001, 0.9), (0.0000001, 0.9)] 
    else:
        gammas0 = np.random.normal(0, 1, size=p)
        betas0 = np.random.normal(0, 1, size=p)
        params = np.concatenate([gammas0, betas0])
        bounds_params = [(0.0000001, np.pi)] * (2*p)

    res = minimize(Cost_function,
            params,
            args=(ising_model, model, qc, backend, p, gammas, betas, LR),
            bounds=bounds_params,
            method="cobyla",
            options={"maxiter": iters})

    params = res.x
    f_energy, qaoa_result = Cost_function(params, ising_model, model, qc, backend, p, gammas, betas, LR, minimize=False)
    
    return res, enrgs, probs_opt, qaoa_result, f_energy, gates

# %%
def run_MCLP(grid_size, instances_dict, p, N, alpha, EqC=2, slack_vars=False, WS=False, LR=False):
    shots = 1000

    data = {}
    data['r'] = []
    data['probs'] = []
    data['success_counter'] = []
    data['qaoa_FR'] = []
    data['t_ws'] = []
    data['gates'] = []
    data['t_qaoa'] = []
    data['t_total'] = []
    data['n_fev'] = []
    data['n_qubits'] = []
    data['size_grid'] = grid_size
    data['gse'] = []
    data['qaoa_e'] = []
    data['opt_cost'] = []
    data['brute_force_list'] = []
    for n in grid_size:
        r_n = []
        probs_n = []
        qaoa_fes = []
        t_ws = []
        t_qaoa = []
        t = []
        n_fev = []
        gse = []
        opt_cost = []
        qaoa_e = []
        count = 0
        print(f'{n} places')
        for l in range(N):
            print(f'{l} experiment')
            J = instances_dict[str(n)][l][0]
            I = np.array(instances_dict[str(n)][l][1])
            I = I / max(I)
            S = 1
            P = int(instances_dict[str(n)][l][2] * 0.5)
            EqC = P
            alpha = np.mean(I)
            model = MCLP(J, I, P, S, version= 'COP', slack_vars=slack_vars)
            n_qubits = model.number_of_variables
            
            backend = AerSimulator()

            t_ws_t = 0
            if WS:
                cont_model = MCLP(J, I, P, S, version= 'CONT', slack_vars=slack_vars)
                t_ws_i = time.time()
                cont_sol = cont_solution(cont_model)
                WS_params = WS_parameters(cont_sol)
                t_ws_f = time.time()
                t_ws_t = t_ws_f-t_ws_i
            else:
                WS_params = None
            t_ws.append(t_ws_t)
            
            ising_model = QUBOtoIsingModel(
                model,
                include='Total', 
                normalize=False, 
                obj_normalize=False, 
                pen_normalize=False, 
                UP=not slack_vars,
                alpha=alpha, 
                gamma=0, 
                EqC=EqC,
                precision=6
            )
    
            t_qaoa_i = time.time()
            res, energies, probs, qaoa_result, qaoa_energy, gates = min_QAOA(model, ising_model, p, backend, LR=LR, WS_params=WS_params, iters=1000)
            qaoa_e.append(qaoa_energy)
            n_fev.append(res.nfev)
            t_qaoa_f = time.time()
            t_qaoa_t = t_qaoa_f - t_qaoa_i
            t_qaoa.append(t_qaoa_t)
            t.append(t_ws_t + t_qaoa_t)
            opt_sol = solution(model)
            opt_sol_cost = compute_cost({opt_sol:1}, ising_model)
            opt_cost.append(opt_sol_cost)
            probs = qaoa_result.get(opt_sol,0)/shots
            probs_n.append(probs)

            e_min = 0
            brute_force_list = list(BruteForceSolutions(model, alpha, 0, EqC=EqC,
                                    UP=not slack_vars, 
                                    include='Total', 
                                    normalize=False, 
                                    obj_normalize=False,
                                    pen_normalize=False).items())
            s_min = brute_force_list[0][0]
            e_min = brute_force_list[0][1]
            e_max = brute_force_list[-1][1]

            if s_min==opt_sol:
                print('Correct Penalization')
                count +=1
            gse.append(e_min)
            
            r = (qaoa_energy - e_max) / (e_min - e_max)
            r_n.append(r)
                
            fes = 0
            for s, c in qaoa_result.items():
                fes += check_feasibility(model, s) * c / shots
            qaoa_fes.append(fes)
            print(f"r: {r}, probs: {probs}, t: {t_ws_t + t_qaoa_t}")
        print(f'BF fes: {count/N}')
        data['n_qubits'].append(n_qubits) 
        data['success_counter'].append(count/N)
        data['qaoa_FR'].append(qaoa_fes)
        data['qaoa_e'].append(qaoa_e)
        data['r'].append(r_n)
        data['probs'].append(probs_n)
        data['opt_cost'].append(opt_cost)
        data['t_ws'].append(t_ws)
        data['gates'].append(gates)
        data['t_qaoa'].append(t_qaoa)
        data['t_total'].append(t)
        data['n_fev'].append(n_fev)
        data['gse'].append(gse)
        data['brute_force_list'].append(brute_force_list)
    return data

# %%
grid_size = [[2, 2], [2, 3], [2, 4], [3, 3], [3, 4]]

p = 50
N = 10
alpha = None # alpha is defined inside run_MCLP

data = {}
file_name = f"MCLP_Ns_data6_p_{p}_1000.txt"


print('UP')
data['UP'] = run_MCLP(grid_size, instances_dict, p, N, alpha, slack_vars=False, WS=False, LR=False)
with open(file_name, "w") as file:
    file.write(str(data))
file.close()

print('UP_LR')
data['UP_LR'] = run_MCLP(grid_size, instances_dict, p, N, alpha, slack_vars=False, WS=False, LR=True)
with open(file_name, "w") as file:
    file.write(str(data))
file.close()

print('UP_WS')
data['UP_WS'] = run_MCLP(grid_size, instances_dict, p, N, alpha, slack_vars=False, WS=True, LR=False)
with open(file_name, "w") as file:
    file.write(str(data))
file.close()

print('UP_WS_LR')
data['UP_WS_LR'] = run_MCLP(grid_size, instances_dict, p, N, alpha, slack_vars=False, WS=True, LR=True)
with open(file_name, "w") as file:
    file.write(str(data))
file.close()
# Out:
# UP
# [2, 2] places
# 0 experiment
# Correct Penalization
# r: 0.6345999999999999, probs: 0.031, t: 62.7599356174469
# 1 experiment
# Correct Penalization
# r: 0.7086833333333333, probs: 0.097, t: 63.00700879096985
# 2 experiment
# Correct Penalization
# r: 0.7538148148148148, probs: 0.077, t: 86.07768607139587
# 3 experiment
# Correct Penalization
# r: 0.7017666666666666, probs: 0.098, t: 74.50399565696716
# 4 experiment
# Correct Penalization
# r: 0.7306756756756757, probs: 0.006, t: 70.51110744476318
# 5 experiment
# Correct Penalization
# r: 0.7629600000000001, probs: 0.075, t: 71.11812019348145
# 6 experiment
# Correct Penalization
# r: 0.6825217391304348, probs: 0.121, t: 68.28298830986023
# 7 experiment
# Correct Penalization
# r: 0.7392173913043478, probs: 0.201, t: 71.06652522087097
# 8 experiment
# Correct Penalization
# r: 0.7366756756756757, probs: 0.148, t: 70.6741304397583
# 9 experiment
# Correct Penalization
# r: 0.6686470588235294, probs: 0.025, t: 69.63285946846008
# BF fes: 1.0
# [2, 3] places
# 0 experiment
# r: 0.6505597484276731, probs: 0.0, t: 94.86905908584595
# 1 experiment
# Correct Penalization
# r: 0.7738026315789472, probs: 0.001, t: 106.88826322555542
# 2 experiment
# r: 0.6745263157894736, probs: 0.002, t: 92.5267391204834
# 3 experiment
# Correct Penalization
# r: 0.7443333333333333, probs: 0.006, t: 117.40322780609131
# 4 experiment
# Correct Penalization
# r: 0.7167301587301587, probs: 0.0, t: 99.59693121910095
# 5 experiment
# Correct Penalization
# r: 0.7119066666666667, probs: 0.002, t: 109.05989074707031
# 6 experiment
# r: 0.7454238683127572, probs: 0.0, t: 117.9573769569397
# 7 experiment
# Correct Penalization
# r: 0.6995380434782609, probs: 0.001, t: 98.7936658859253
# 8 experiment
# r: 0.730574074074074, probs: 0.001, t: 117.27754473686218
# 9 experiment
# r: 0.8337469135802471, probs: 0.02, t: 115.9160988330841
# BF fes: 0.5
# [2, 4] places
# 0 experiment
# Correct Penalization
# r: 0.7278094302554029, probs: 0.001, t: 177.17851567268372
# 1 experiment
# Correct Penalization
# r: 0.7043794871794873, probs: 0.001, t: 179.41899180412292
# 2 experiment
# Correct Penalization
# r: 0.7019295774647887, probs: 0.002, t: 164.67150712013245
# 3 experiment
# Correct Penalization
# r: 0.6708691588785046, probs: 0.001, t: 184.0203516483307
# 4 experiment
# Correct Penalization
# r: 0.7067758620689656, probs: 0.0, t: 177.83710622787476
# 5 experiment
# Correct Penalization
# r: 0.7748517857142858, probs: 0.0, t: 182.84900784492493
# 6 experiment
# Correct Penalization
# r: 0.7455199004975125, probs: 0.0, t: 180.66437578201294
# 7 experiment
# Correct Penalization
# r: 0.7233852459016393, probs: 0.0, t: 188.14197254180908
# 8 experiment
# Correct Penalization
# r: 0.7753427419354839, probs: 0.001, t: 173.3093912601471
# 9 experiment
# Correct Penalization
# r: 0.6452468354430381, probs: 0.0, t: 145.02734875679016
# BF fes: 1.0
# [3, 3] places
# 0 experiment
# Correct Penalization
# r: 0.7248967391304348, probs: 0.0, t: 230.2067060470581
# 1 experiment
# Correct Penalization
# r: 0.7069363957597172, probs: 0.001, t: 207.41628170013428
# 2 experiment
# Correct Penalization
# r: 0.7059339378238342, probs: 0.0, t: 215.02621722221375
# 3 experiment
# r: 0.6899938650306748, probs: 0.0, t: 183.01527643203735
# 4 experiment
# Correct Penalization
# r: 0.697905840286055, probs: 0.0, t: 221.06714963912964
# 5 experiment
# Correct Penalization
# r: 0.6435959271168276, probs: 0.0, t: 211.1370849609375
# 6 experiment
# Correct Penalization
# r: 0.6867166123778501, probs: 0.0, t: 173.05741548538208
# 7 experiment
# Correct Penalization
# r: 0.7169353369763206, probs: 0.0, t: 207.0663902759552
# 8 experiment
# Correct Penalization
# r: 0.6717837837837838, probs: 0.002, t: 186.85614681243896
# 9 experiment
# Correct Penalization
# r: 0.6453146067415733, probs: 0.0, t: 201.30789494514465
# BF fes: 0.9
# [3, 4] places
# 0 experiment
# Correct Penalization
# r: 0.7507133126934984, probs: 0.0, t: 401.9838607311249
# 1 experiment
# Correct Penalization
# r: 0.7539641434262948, probs: 0.0, t: 510.2714858055115
# 2 experiment
# Correct Penalization
# r: 0.7794, probs: 0.0, t: 599.5545101165771
# 3 experiment
# Correct Penalization
# r: 0.7566191117092866, probs: 0.0, t: 478.5818645954132
# 4 experiment
# r: 0.8011213151927438, probs: 0.0, t: 81.46335196495056
# 5 experiment
# Correct Penalization
# r: 0.7760730816077953, probs: 0.0, t: 459.98671197891235
# 6 experiment
# Correct Penalization
# r: 0.7672489296636086, probs: 0.0, t: 61.57717728614807
# 7 experiment
# Correct Penalization
# r: 0.7719986413043477, probs: 0.0, t: 515.0700478553772
# 8 experiment
# Correct Penalization
# r: 0.7685734767025091, probs: 0.0, t: 477.4787211418152
# 9 experiment
# Correct Penalization
# r: 0.7554969072164949, probs: 0.0, t: 468.67822766304016
# BF fes: 0.9
# UP_LR
# [2, 2] places
# 0 experiment
# Correct Penalization
# r: 0.99915, probs: 0.319, t: 2.038085699081421
# 1 experiment
# Correct Penalization
# r: 0.9916666666666667, probs: 0.925, t: 2.020185947418213
# 2 experiment
# Correct Penalization
# r: 0.9898333333333332, probs: 0.729, t: 2.0017707347869873
# 3 experiment
# Correct Penalization
# r: 0.9932333333333333, probs: 0.952, t: 2.1188864707946777
# 4 experiment
# Correct Penalization
# r: 0.9892432432432432, probs: 0.646, t: 2.009106159210205
# 5 experiment
# Correct Penalization
# r: 0.9892799999999999, probs: 0.74, t: 2.1909732818603516
# 6 experiment
# Correct Penalization
# r: 0.9789565217391304, probs: 0.753, t: 1.8225176334381104
# 7 experiment
# Correct Penalization
# r: 0.9824347826086959, probs: 0.788, t: 1.9482262134552002
# 8 experiment
# Correct Penalization
# r: 0.9901081081081081, probs: 0.647, t: 1.8958253860473633
# 9 experiment
# Correct Penalization
# r: 0.9910882352941176, probs: 0.853, t: 2.505540132522583
# BF fes: 1.0
# [2, 3] places
# 0 experiment
# r: 0.9965094339622644, probs: 0.1, t: 3.4473040103912354
# 1 experiment
# Correct Penalization
# r: 0.9854342105263157, probs: 0.445, t: 3.493445634841919
# 2 experiment
# r: 0.9955438596491227, probs: 0.005, t: 3.1190216541290283
# 3 experiment
# Correct Penalization
# r: 0.9819212121212122, probs: 0.482, t: 3.3653476238250732
# 4 experiment
# Correct Penalization
# r: 0.9984603174603174, probs: 0.468, t: 3.093207836151123
# 5 experiment
# Correct Penalization
# r: 0.9896266666666667, probs: 0.607, t: 2.9718070030212402
# 6 experiment
# r: 0.985213991769547, probs: 0.122, t: 3.250605821609497
# 7 experiment
# Correct Penalization
# r: 0.9951739130434782, probs: 0.874, t: 3.4820101261138916
# 8 experiment
# r: 0.9893796296296297, probs: 0.194, t: 3.614936351776123
# 9 experiment
# r: 0.9888148148148149, probs: 0.399, t: 3.233339309692383
# BF fes: 0.5
# [2, 4] places
# 0 experiment
# Correct Penalization
# r: 0.994056974459725, probs: 0.695, t: 7.072855472564697
# 1 experiment
# Correct Penalization
# r: 0.9909897435897438, probs: 0.535, t: 5.046347618103027
# 2 experiment
# Correct Penalization
# r: 0.9951455399061032, probs: 0.79, t: 5.519101858139038
# 3 experiment
# Correct Penalization
# r: 0.995700934579439, probs: 0.598, t: 4.57522177696228
# 4 experiment
# Correct Penalization
# r: 0.9949827586206894, probs: 0.747, t: 5.324633359909058
# 5 experiment
# Correct Penalization
# r: 0.994, probs: 0.626, t: 5.732009172439575
# 6 experiment
# Correct Penalization
# r: 0.9913805970149253, probs: 0.79, t: 5.085515260696411
# 7 experiment
# Correct Penalization
# r: 0.9769631147540985, probs: 0.304, t: 6.298902273178101
# 8 experiment
# Correct Penalization
# r: 0.9838145161290323, probs: 0.268, t: 5.291438341140747
# 9 experiment
# Correct Penalization
# r: 0.9857784810126585, probs: 0.353, t: 4.958995819091797
# BF fes: 1.0
# [3, 3] places
# 0 experiment
# Correct Penalization
# r: 0.9943066770186336, probs: 0.692, t: 7.342865705490112
# 1 experiment
# Correct Penalization
# r: 0.9831060070671376, probs: 0.321, t: 5.925526857376099
# 2 experiment
# Correct Penalization
# r: 0.9740051813471501, probs: 0.154, t: 6.4943482875823975
# 3 experiment
# r: 0.9799815950920246, probs: 0.138, t: 6.033534288406372
# 4 experiment
# Correct Penalization
# r: 0.9732300357568535, probs: 0.2, t: 5.80457329750061
# 5 experiment
# Correct Penalization
# r: 0.9871146838156485, probs: 0.466, t: 6.912627220153809
# 6 experiment
# Correct Penalization
# r: 0.9901932681867535, probs: 0.765, t: 7.296058893203735
# 7 experiment
# Correct Penalization
# r: 0.9853998178506376, probs: 0.299, t: 5.70922327041626
# 8 experiment
# Correct Penalization
# r: 0.9865675675675677, probs: 0.652, t: 5.440384864807129
# 9 experiment
# Correct Penalization
# r: 0.9835730337078653, probs: 0.565, t: 5.609581708908081
# BF fes: 0.9
# [3, 4] places
# 0 experiment
# Correct Penalization
# r: 0.9590024767801861, probs: 0.184, t: 14.848947286605835
# 1 experiment
# Correct Penalization
# r: 0.9909096945551129, probs: 0.161, t: 17.45937442779541
# 2 experiment
# Correct Penalization
# r: 0.9891373737373738, probs: 0.336, t: 12.190079927444458
# 3 experiment
# Correct Penalization
# r: 0.9863055181695828, probs: 0.029, t: 13.03681206703186
# 4 experiment
# r: 0.9942698412698413, probs: 0.129, t: 14.394022464752197
# 5 experiment
# Correct Penalization
# r: 0.9899190012180268, probs: 0.251, t: 12.717937231063843
# 6 experiment
# Correct Penalization
# r: 0.9698605504587157, probs: 0.097, t: 16.387409925460815
# 7 experiment
# Correct Penalization
# r: 0.9898872282608697, probs: 0.419, t: 20.607293128967285
# 8 experiment
# Correct Penalization
# r: 0.9619605734767028, probs: 0.046, t: 14.771836519241333
# 9 experiment
# Correct Penalization
# r: 0.9902309278350516, probs: 0.382, t: 19.027281761169434
# BF fes: 0.9
# UP_WS
# [2, 2] places
# 0 experiment
# Correct Penalization
# r: 0.9964999999999999, probs: 0.983, t: 73.2870614528656
# 1 experiment
# Correct Penalization
# r: 0.9901166666666669, probs: 0.954, t: 85.07979011535645
# 2 experiment
# Correct Penalization
# r: 0.9973703703703705, probs: 0.98, t: 72.26260900497437
# 3 experiment
# Correct Penalization
# r: 0.99235, probs: 0.973, t: 86.57223868370056
# 4 experiment
# Correct Penalization
# r: 0.9967567567567568, probs: 0.976, t: 78.12541317939758
# 5 experiment
# Correct Penalization
# r: 0.9900399999999999, probs: 0.95, t: 73.75664043426514
# 6 experiment
# Correct Penalization
# r: 0.9956086956521739, probs: 0.976, t: 77.07956719398499
# 7 experiment
# Correct Penalization
# r: 0.9992608695652175, probs: 0.992, t: 78.04529976844788
# 8 experiment
# Correct Penalization
# r: 0.9987567567567568, probs: 0.994, t: 87.5400698184967
# 9 experiment
# Correct Penalization
# r: 0.9979117647058825, probs: 0.99, t: 86.06880450248718
# BF fes: 1.0
# [2, 3] places
# 0 experiment
# r: 0.9789748427672957, probs: 0.986, t: 125.78178572654724
# 1 experiment
# Correct Penalization
# r: 0.9821052631578947, probs: 0.855, t: 15.310786008834839
# 2 experiment
# r: 0.9455263157894737, probs: 0.983, t: 128.68950724601746
# 3 experiment
# Correct Penalization
# r: 0.9966242424242425, probs: 0.949, t: 130.17593836784363
# 4 experiment
# Correct Penalization
# r: 0.9931164021164021, probs: 0.936, t: 15.5574312210083
# 5 experiment
# Correct Penalization
# r: 0.9932533333333334, probs: 0.898, t: 116.09105634689331
# 6 experiment
# r: 0.9707942386831275, probs: 0.936, t: 129.81120800971985
# 7 experiment
# Correct Penalization
# r: 0.9982119565217391, probs: 0.989, t: 127.93352103233337
# 8 experiment
# r: 0.9856759259259258, probs: 0.987, t: 125.91859149932861
# 9 experiment
# r: 0.9764197530864199, probs: 0.917, t: 115.53716969490051
# BF fes: 0.5
# [2, 4] places
# 0 experiment
# Correct Penalization
# r: 0.9966404715127701, probs: 0.95, t: 208.16802787780762
# 1 experiment
# Correct Penalization
# r: 0.9968871794871796, probs: 0.937, t: 211.0869436264038
# 2 experiment
# Correct Penalization
# r: 0.9951643192488262, probs: 0.913, t: 205.24644112586975
# 3 experiment
# Correct Penalization
# r: 0.9910280373831772, probs: 0.932, t: 201.66626715660095
# 4 experiment
# Correct Penalization
# r: 0.9972672413793101, probs: 0.955, t: 217.78745317459106
# 5 experiment
# Correct Penalization
# r: 0.9950500000000001, probs: 0.911, t: 208.19782996177673
# 6 experiment
# Correct Penalization
# r: 0.9914477611940299, probs: 0.897, t: 27.980233430862427
# 7 experiment
# Correct Penalization
# r: 0.9958934426229509, probs: 0.955, t: 214.6010398864746
# 8 experiment
# Correct Penalization
# r: 0.9976451612903227, probs: 0.955, t: 215.41178798675537
# 9 experiment
# Correct Penalization
# r: 0.9928164556962025, probs: 0.946, t: 214.10424065589905
# BF fes: 1.0
# [3, 3] places
# 0 experiment
# Correct Penalization
# r: 0.9946987577639753, probs: 0.868, t: 271.129919052124
# 1 experiment
# Correct Penalization
# r: 0.9764734982332156, probs: 0.745, t: 30.781795263290405
# 2 experiment
# Correct Penalization
# r: 0.9963743523316061, probs: 0.95, t: 285.97896695137024
# 3 experiment
# r: 0.9964907975460122, probs: 0.944, t: 281.68646717071533
# 4 experiment
# Correct Penalization
# r: 0.9890226460071515, probs: 0.899, t: 251.41623616218567
# 5 experiment
# Correct Penalization
# r: 0.9906120042872455, probs: 0.858, t: 272.8098084926605
# 6 experiment
# Correct Penalization
# r: 0.9942562432138979, probs: 0.936, t: 250.8574182987213
# 7 experiment
# Correct Penalization
# r: 0.9988542805100185, probs: 0.98, t: 295.16995644569397
# 8 experiment
# Correct Penalization
# r: 0.9948378378378377, probs: 0.905, t: 285.26045393943787
# 9 experiment
# Correct Penalization
# r: 0.993426966292135, probs: 0.91, t: 274.6566016674042
# BF fes: 0.9
# [3, 4] places
# 0 experiment
# Correct Penalization
# r: 0.9969188854489166, probs: 0.942, t: 539.8202273845673
# 1 experiment
# Correct Penalization
# r: 0.8874395750332006, probs: 0.0, t: 584.8076138496399
# 2 experiment
# Correct Penalization
# r: 0.9954929292929292, probs: 0.941, t: 514.4279625415802
# 3 experiment
# Correct Penalization
# r: 0.9934414535666217, probs: 0.844, t: 540.6725313663483
# 4 experiment
# r: 0.9948083900226757, probs: 0.875, t: 490.708970785141
# 5 experiment
# Correct Penalization
# r: 0.9722978075517662, probs: 0.685, t: 59.93407344818115
# 6 experiment
# Correct Penalization
# r: 0.9972324159021407, probs: 0.845, t: 477.6955256462097
# 7 experiment
# Correct Penalization
# r: 0.9954184782608695, probs: 0.929, t: 468.8498501777649
# 8 experiment
# Correct Penalization
# r: 0.9907383512544804, probs: 0.796, t: 65.83404302597046
# 9 experiment
# Correct Penalization
# r: 0.9966412371134022, probs: 0.925, t: 636.0614895820618
# BF fes: 0.9
# UP_WS_LR
# [2, 2] places
# 0 experiment
# Correct Penalization
# r: 0.9998999999999999, probs: 0.998, t: 2.166693687438965
# 1 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.3797516822814941
# 2 experiment
# Correct Penalization
# r: 0.9998518518518519, probs: 0.999, t: 2.181925058364868
# 3 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.7130484580993652
# 4 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.6029772758483887
# 5 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.3288674354553223
# 6 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.7593035697937012
# 7 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.3923768997192383
# 8 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.5490877628326416
# 9 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 1.6801741123199463
# BF fes: 1.0
# [2, 3] places
# 0 experiment
# r: 0.9811320754716982, probs: 1.0, t: 2.26666522026062
# 1 experiment
# Correct Penalization
# r: 0.9999868421052631, probs: 0.999, t: 3.235553026199341
# 2 experiment
# r: 0.9473684210526314, probs: 1.0, t: 2.441033363342285
# 3 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 3.285013198852539
# 4 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 2.746342897415161
# 5 experiment
# Correct Penalization
# r: 0.99996, probs: 0.999, t: 3.60420298576355
# 6 experiment
# r: 0.9753086419753085, probs: 1.0, t: 2.701554775238037
# 7 experiment
# Correct Penalization
# r: 0.9999673913043479, probs: 0.999, t: 3.1462173461914062
# 8 experiment
# r: 0.986111111111111, probs: 1.0, t: 3.8377368450164795
# 9 experiment
# r: 0.9814814814814816, probs: 1.0, t: 4.241919755935669
# BF fes: 0.5
# [2, 4] places
# 0 experiment
# Correct Penalization
# r: 0.9999921414538311, probs: 0.999, t: 5.241939067840576
# 1 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 4.474889039993286
# 2 experiment
# Correct Penalization
# r: 0.9999389671361502, probs: 0.997, t: 6.772066116333008
# 3 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 4.997076988220215
# 4 experiment
# Correct Penalization
# r: 0.9999913793103449, probs: 0.999, t: 6.850472927093506
# 5 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 3.602025270462036
# 6 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 4.26127290725708
# 7 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 4.149262428283691
# 8 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 4.4025719165802
# 9 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 5.064460754394531
# BF fes: 1.0
# [3, 3] places
# 0 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 5.899996519088745
# 1 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 6.3989081382751465
# 2 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 6.338109016418457
# 3 experiment
# r: 0.9998895705521472, probs: 0.998, t: 8.827882051467896
# 4 experiment
# Correct Penalization
# r: 0.999989272943981, probs: 0.999, t: 5.518522024154663
# 5 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 4.6740076541900635
# 6 experiment
# Correct Penalization
# r: 0.9999902280130294, probs: 0.999, t: 6.544864654541016
# 7 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 6.045406818389893
# 8 experiment
# Correct Penalization
# r: 0.9999729729729729, probs: 0.998, t: 6.436197519302368
# 9 experiment
# Correct Penalization
# r: 0.9999775280898877, probs: 0.999, t: 8.852980375289917
# BF fes: 0.9
# [3, 4] places
# 0 experiment
# Correct Penalization
# r: 0.9999888544891641, probs: 0.997, t: 17.879199266433716
# 1 experiment
# Correct Penalization
# r: 0.9270677290836654, probs: 0.0, t: 21.088247776031494
# 2 experiment
# Correct Penalization
# r: 0.9998383838383837, probs: 0.997, t: 16.40740728378296
# 3 experiment
# Correct Penalization
# r: 0.9999158815612381, probs: 0.999, t: 14.936168193817139
# 4 experiment
# r: 0.9999965986394557, probs: 0.999, t: 16.448245525360107
# 5 experiment
# Correct Penalization
# r: 0.9999926918392205, probs: 0.999, t: 16.771469593048096
# 6 experiment
# Correct Penalization
# r: 0.9997088685015292, probs: 0.998, t: 17.045676469802856
# 7 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 15.470766544342041
# 8 experiment
# Correct Penalization
# r: 0.9999928315412187, probs: 0.999, t: 13.492617845535278
# 9 experiment
# Correct Penalization
# r: 1.0, probs: 1.0, t: 18.22721529006958
# BF fes: 0.9
